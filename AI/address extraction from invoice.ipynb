# %% [markdown]
# ## address extraction algorithm
# ### (0) pdf pages are  converted to images
# ### (1) Region of interest is searched in invoice image through object detection with OPENCV. These region of interest are blocks of text in an invoice.
# ### (2) The blocks of text from invoice is extracted through OCR.
# ### (3) Each Block of text is checked , if it could be an address or not using spacy and some clever heuristics like not having a comma delimeter in an address or non alphabetical character like @ in an address which may depict an email
# ### (4) The address type with machine learning(SPACY Named entity recognition)  is not only limited to indian address.
# ### (5) The address is not labelled like "from address" or "to address" , "source" / "Destination" so , we will take first 2 address found in an invoice as source and destination address.
# ### (6) preprocess address text to remove discrepencies (Ex. time).

# %%
import pdfplumber #convert pdf to image
import numpy as np 
import cv2 # for text block detection
import os
import pytesseract #image to text (OCR)
import spacy 
# Load spacy NER model
nlp = spacy.load("en_core_web_md")

# %%
def check_address(text):
    # Assumption: Address contains commas as seperator
    if ',' not in text: # Check if text doesn't have comma delimeter.
        return False
    # Assumption: Address Doesn't contain emails and hence no @ symbol 
    if '@' in text: # spacy considers text containing gmail address as location , so text containing gmail can never be address
        return False
    # this was an edge case found in invoices, through spacy NER , text containing thanks was also considered as location.
    if 'thank' in text : 
        return False
    doc = nlp(text)
    # Check if location is found in address 
    for entity in doc.ents:
        if entity.label_=='GPE' or entity.label_=='LOC':
            return True
    return False

# %%
def image_to_rect(img):
    ret, thresh1 = cv2.threshold(img, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)
    rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (16,16))   
    dilation = cv2.dilate(thresh1, rect_kernel, iterations = 3) 
    contours, _ = cv2.findContours(dilation,  cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
    index=1
    for cnt in contours[::-1]: 
        x, y, w, h = cv2.boundingRect(cnt) 
        cropped = img[y:y + h, x:x + w]
        text=pytesseract.image_to_string(cropped)
        if check_address(text):
            text=text.replace('\n',' ')
            print(f"({index}) {text}")
            index+=1
            
def generate_address_box(file):
    pdf=pdfplumber.open(file)
    print('file_name:',file)
    for page in pdf.pages:
      img=np.array(page.to_image(resolution=300).original.convert('L'))
      print(f'page {page.page_number} contains address:')
      image_to_rect(img)

# %%
path=os.getcwd()+'/pdf_dataset'
files=os.listdir(path)
for file in files:
  generate_address_box(path+'/'+file)
# Out:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_25.pdf
# page 1 contains address:
# (1) 55, Gopalpura Road, Chhayadip Nagar, Shri Gopal Nagar, Gopal Pura Mode, Jaipur
# (2) Unnamed Road, Bhakrota, Jaipur
# page 2 contains address:
# (1) Pickup Address 55, Gopalpura Road, Chhayadip Nagar, Shri Gopal Nagar, Gopal Pura Mode, Jaipur
# page 3 contains address:
# (1) ANI Technologies Pvt. Ltd.  Office unit 405 - 406, fourth floor, southend squire, mansarover industrial area, new sanganer road, Jaipur South 302020
# (2) Supply Address Office unit 405 - 406, fourth floor, southend squire, mansarover industrial area, new sanganer road, Jaipur South 302020
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_3.pdf
# page 1 contains address:
# (1) e Road Number 23, Andheri East, Mumbai, Maharashtra, India
# (2) Karjat - Murbad Rd, Kotwal Nagar, Deulwadi, Karjat
# page 2 contains address:
# (1) Road Number 23, Andheri East, Mumbai, Maharashtra, India
# page 3 contains address:
# (1) Gala No. 07, Ground floor, Amfotech Park, Plot No - A/ 26, Road No. B-8, Wagle Ind. Estate, Thane West-400604
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_11.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 17:07  Haware Infotech Park, Sector 30A, Vashi, Navi Mumbai, Maharashtra 400703, India
# (2) 18:20  7, Dongripada, Thane West, Thane, Maharashtra 400607, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER
India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_14.pdf
# page 1 contains address:
# (1) « Platina Building, G Block BKC, Bandra Kurla Complex, Bandra East, Mumbai, Maharashtra 400051, India
# (2) Narpat raj bafna, 150ft road, Bhayandar Flyover, Mira Road West, Mira Bhayandar
# page 2 contains address:
# (1) Platina Building, G Block BKC, Bandra Kurla Complex, Bandra East, Mumbai, Maharashtra 400051, India
# page 3 contains address:
# (1) Gala No. 07, Ground floor, Amfotech Park, Plot No - A/ 26, Road No. B-8, Wagle Ind. Estate, Thane West-400604
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_21.pdf
# page 1 contains address:
# (1) 02:53pm | Casa Paradiso, Allauddin Basthi, Sanath Nagar, Hyderabad, Telangana 500018, India
# (2) 03:50pm | Departure Dr, Shamshabad, Hyderabad, Telangana 501218, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_26.pdf
# page 1 contains address:
# (1) ® 08:54am | 187, Block D, Sector 61, Noida, Uttar Pradesh 201301, India
# (2) ® 09:49am | 2/45, Block 2, Geeta Colony, a$ feeei, Delhi 110031, India
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_4.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 05:13pm 904, Trishla City, Nabha, Punjab 160403, India
# (2) 05:34pm  New Civil Air Terminal, Mohali District, Sahibzada Ajit Singh Nagar, Punjab 140306, India
# page 3 contains address:
# page 4 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_15.pdf
# page 1 contains address:
# (1) 18C, Knowledge Park Ill, Noida, Uttar Pradesh 201310, India
# page 2 contains address:
# (1) Customer Pick Up Address 18C, Knowledge Park III, Noida, Uttar Pradesh 201310, India
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# (2) Vijayguna 18C, Knowledge Park III, Noida, Uttar Pradesh 201310, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_16.pdf
# page 1 contains address:
# (1) e A-WING, Mira Bhayandar Rd, Pleasant Park, Mira Road, Mira Bhayandar
# (2) Chhatrapati Shivaji Terminus, Fort, Mumbai
# page 2 contains address:
# (1) A-WING, Mira Bhayandar Rd, Pleasant Park, Mira Road, Mira Bhayandar
# page 3 contains address:
# (1) Gala No. 07, Ground floor, Amfotech Park, Plot No - A/ 26, Road No. B-8, Wagle Ind. Estate, Thane West-400604
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_16.pdf
# page 1 contains address:
# (1) India Expo Mart Cir, Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# (2) © 2C, near IIMT College, Knowledge Park III, Greater Noida, Uttar Pradesh 201310, India
# page 2 contains address:
# (1) Customer Pick Up Address India Expo Mart Cir, Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# (2) Vijayguna India Expo Mart Cir, Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_22.pdf
# page 1 contains address:
# (1) 8:31 | 1431/1, 4th Cross Rd, Rashad Nagar, Govindapura, HBR Layout, Bengaluru, Karnataka 560045, India
# (2) 9:14 | RK Puram, Gandhi Nagar, Bengaluru, Karnataka 560009, India
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_15.pdf
# page 1 contains address:
# page 2 contains address:
# (1) DLF Phase 5, Sector 54, Gurugram, Haryana 122002,  India
# (2) 12:59pm Delhi, 110037, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_18.pdf
# page 1 contains address:
# (1) =  Road Number CE124  Salt lake, Sector — 1, Kolkata India  19 NS Road, HMP House  BBD Bagh, Dalhousie, Kolkata India
# page 2 contains address:
# (1) Road Number 23, Andheri East, Mumbai, Maharashtra, India
# page 3 contains address:
# (1) Gala No. 07, Ground floor, Amfotech Park, Plot No - A/ 26, Road No. B-8, Wagle Ind. Estate, Thane West-400604
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_4.pdf
# page 1 contains address:
# (1) Unnamed Road, Kavuri Hills Phase 1, Kavuri Hills, Jubilee Hills, Hyderabad, Telangana 500033, India  e Block YSR Residency, Barkatpura Rd, Chitrapuri Colony, Lingampally, Kachiguda, Hyderabad, Telangana 500027, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_6.pdf
# page 1 contains address:
# (1) 40, Moosapet Cross Rd, Pragathi Nagar, Moosapet, Hyderabad, Telangana 500018, India
# (2) © CGM2+GHR, Railway Officer Colony, Botiguda, Bhoiguda, Secunderabad, Telangana 500003, India
# page 2 contains address:
# (1) Customer Pick Up Address 40, Moosapet Cross Rd, Pragathi Nagar, Moosapet, Hyderabad, Telangana 500018, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_24.pdf
# page 1 contains address:
# (1) 08:02pm | Delhi, 110037, India
# (2) 09:04pm | MS-4, Kendriya Vihar, Sector 56, Gurugram, Haryana 122011, India
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_15.pdf
# page 1 contains address:
# (1) « 13, Navpada, CS International Airport Area, Vile Parle, Mumbai, Maharashtra 400099, India
# (2) Narpat raj bafna, 150ft road, Bhayandar Flyover, Mira Road West, Mira Bhayandar
# page 2 contains address:
# (1) 13, Navpada, CS International Airport Area, Vile Parle, Mumbai, Maharashtra 400099, India
# page 3 contains address:
# (1) Gala No. 07, Ground floor, Amfotech Park, Plot No - A/ 26, Road No. B-8, Wagle Ind. Estate, Thane West-400604
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_39.pdf
# page 1 contains address:
# (1) 8:26 pm | Sant Nagar, Sundar Nagar, New Delhi, Delhi 110003, India
# (2) 8:48 pm| Narmadeshwar Niwas (beside Narmadeshwar Shiv Mandir B Block, Sector 62, Nearby B block market, Block B, Industrial Area, Sector 62, Noida, Uttar Pradesh 201309, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_38.pdf
# page 1 contains address:
# (1) 4:56 pm| Hyderabad - Ramagundam Rd, Shamirpet, Secunderabad, Telangana 500078, India
# (2) 6:08 pm | #65/A Vengalrao Nagar, East Srinivas Nagar Colony, Sanjeeva Reddy Nagar Office Area, Sanjeeva Reddy Nagar, Hyderabad, Telangana 500038, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_4.pdf
# page 1 contains address:
# (1) Minimum bill of =100 for the first 4 km and %8/km thereafter. Ride time at 71.0 per min, includes waiting time during the trip.  Additional service tax is applicable on your fare. Total fare includes this additional service tax. Total bill also includes any toll, MCD or state tax if applicable.Click here for details.  We levy Peak Pricing charges when the demand is high, so that we can make more cabs available to you and continue to serve you efficiently.  For queries or complaints, please visit our Support page  This is an electronically generated invoice and does not require signature. All terms and conditions are as given on  www.olacabs.com.  A Wing’ Sunteck Centre, 37-40 Subhash Road, Off. Western Express Highway, Vile Parle (East), Mumbai - 400057 Service lax # AAJCA1389GS D001, Service Tax Category Cab Operator, PAN No. AAJCA1389G,  CIN:U72900MH2010P TC 240894 Rl: +91 22 3355 3355, Fax: 022 30947974 www.olacabs.com  ©ANI Technologies Pvt. Ltd
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_25.pdf
# page 1 contains address:
# (1) 04:31pm | Park Plaza, Mother Teresa Sarani, Taltala, Kolkata, West Bengal 700016, India
# (2) 05:11pm | Biswa Bangla Sarani, Action Area IIE, Sukanta Pally, Newtown, New Town, West Bengal 700157, India
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_18.pdf
# page 1 contains address:
# (1) Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# page 2 contains address:
# (1) Customer Pick Up Address Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# (2) Vijayguna Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_31.pdf
# page 1 contains address:
# (1) ® 14:43 | 12, Khatipura Rd, Parivahan Nagar, Khatipura, Jaipur, Rajasthan 302012, India
# (2) ® 15:07 | SB-108, Sawai Mansingh Rd, Bapu Nagar, Jaipur, Rajasthan 302007, India
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_17.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 08:05pm  6-3-581/1/1, Anand Nagar Rd, Venkataraman Colony, Khairtabad, Hyderabad, Telangana 500004, India
# (2) 08:30pm  Nimboliadda, Kachiguda, Hyderabad, Telangana 500027, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_19.pdf
# page 1 contains address:
# (1) ~ 201310, near Punjab National Bank, Amritpuram, Block E, Chandila, Gamma 1, Greater Noida, Uttar Pradesh 201308, India
# (2) FG52+X65, Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# page 2 contains address:
# (1) Customer Pick Up Address  201310, near Punjab National Bank, Amritpuram, Block E, Chandila, Gamma 1, Greater Noida, Uttar Pradesh 201308, India
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# (2) Vijayguna  201310, near Punjab National Bank, Amritpuram, Block E, Chandila, Gamma 1, Greater Noida, Uttar Pradesh 201308, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_2.pdf
# page 1 contains address:
# (1) Note: This is an electronically generated invoice and does not require signature. All terms and conditions are as given on www.olacabs.com.  A Wing’ Sunteck Centre, 37-40 Subhash Road, Off. Western Express Highway, Vile Parle (East), Mumbai - 400057 Service lax # AAJCA1389GS D001, Service Tax Category Cab Operator, PAN No. AAJCA1389G, CIN:U72900MH2010P TC 240894 Rl: +91 22 3355 3355, Fax: 022 30947974 www.olacabs.com  ©ANI Technologies Pvt. Ltd
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_34.pdf
# page 1 contains address:
# page 2 contains address:
# (1) Jasmine Heights, JCOW+H36,
# (2) Rajarhat, West Bengal
# (3) 700157, India
# (4) 30, Action Area |, Newtown,
# (5) New Town, West Bengal
# (6) 700156, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_6.pdf
# page 1 contains address:
# (1) « B-74, Mehuwala Mafi, Dehradun, Uttarakhand 248171, India
# (2) 824X+39V, Model Colony, Araghar, Dharampur, Dehradun
# (3) In case of any complaint/grievance against this invoice, write to us at  Grievance officer, ANI Technologies Private Limited, Ola Campus, Prestige RMZ star tech, C wing, Koramangala Industrial layout, Koramangala, Hosur road, Bengaluru, Karnataka, 560095
# page 2 contains address:
# (1) B-74, Mehuwala Mafi, Dehradun, Uttarakhand 248171, India
# (2) Please note the following terms: This invoice is issued by ANI Technologies Private Limited in the capacity of an Electronic Commerce Operator as per Section 9(5) of the Central Goods and Tax Act, 2017 and corresponding provision(s) of the State/ UT GST laws. This invoice has been issued and signed by the Authorized signatory of ANI Technologies Private Limited only for the limited purpose of complying with the requirement under the GST law as an Electronic  Commerce Operator.
# page 3 contains address:
# (1) ANI Technologies Pvt Ltd., 825/1 Kaulagarh Road Street No. 2A, Rajender Nagar, Dehradun 248001
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_19.pdf
# page 1 contains address:
# (1) 09:55am | Krishnappa Garden, C V Raman Nagar, Bengaluru, Karnataka 560075, India
# (2) 10:23am | Windmills of Your Mind, 331, 5B Rd, Shivaji Nagar, KIADB Export Promotion Industrial Area, Whitefield, Bengaluru, Karnataka 560066, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_13.pdf
# page 1 contains address:
# (1) 281c, near IIMT, Knowledge Park Ill, Greater Noida, Uttar Pradesh 201310, India
# (2) FG53+M6 Greater Noida, Uttar Pradesh, India
# page 2 contains address:
# (1) Customer Pick Up Address 281c, near IIMT, Knowledge Park III, Greater Noida, Uttar Pradesh 201310, India
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# (2) Vijayguna 281c, near IIMT, Knowledge Park III, Greater Noida, Uttar Pradesh 201310, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_5.pdf
# page 1 contains address:
# page 2 contains address:
# (1) DLF Phase 5, Sector 54, Gurugram, Haryana 122002,  India
# (2) Delhi, 110037, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_7.pdf
# page 1 contains address:
# (1) 786, 1st Main Rd, 1st Block, Dubasi Palya, Kengeri Satellite Town, Bengaluru, Karnataka 560059, India
# (2) ATC Tower, BIAL Road, Bengaluru
# page 2 contains address:
# (1) Manjunatha L J Ola Mini, Etios Liva  es KAO5AF 1513  Operator State/UT: Karnataka
# (2) Kengeri Satellite Town, Bengaluru, Karnataka 560059,  India
# page 3 contains address:
# (1) ANI Technologies Pvt. Ltd.  5th Floor, Maruthi Infotech Center, 100 Feet Rd, Embassy Golf Links Business Park, Domlur, Bengaluru, Karnataka 560
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_12.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 05:24pm  NSCBI Airport,Dum Dum, Airport Terminal 2, International Airport, Dum Dum, Kolkata, West Bengal 700052, India
# page 3 contains address:
# (1) Nagar, Tollygunge, Kolkata, West Bengal 700040, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_9.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 09:15pm  189, Udyog Vihar Phase 1, Udyog Vihar, Sector 20, Gurugram, Haryana 122008,  India
# (2) 09:44pm  6/82, Jnarera, Jharera Village, Delhi Cantonment, New Delhi, Delhi 110010,
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_10.pdf
# page 1 contains address:
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_22.pdf
# page 1 contains address:
# (1) Base Fare of %80. for the first 4 km and =10/km thereafter. Ride time at =1.0 per min after first 5 min, includes waiting time during the trip.  Additional service tax is applicable on your fare. Total fare includes this additional service tax. Toll and parking charges are extra.  We levy Peak Pricing charges when the demand is high, so that we can make more cabs available to you and continue to serve you efficiently.  For queries or complaints, please visit our Support page  This is an electronically generated invoice and does not require signature. All terms and conditions are as given on  www.olacabs.com.  A Wing’ Sunteck Centre, 37-40 Subhash Road, Off. Western Express Highway, Vile Parle (East), Mumbai - 400057 Service lax # AAJCA1389GS D001, Service Tax Category Cab Operator, PAN No. AAJCA1389G, CIN:U72900MH2010P TC 240894  Rl: +91 22 3355 3355, Fax: 022 30947974 www.olacabs.com ©ANI Technologies Pvt. Ltd
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_27.pdf
# page 1 contains address:
# (1) 06:45  4th Main,Ramapriya Brundavan gardan Arehallii, Bengaluru, Karnataka 560061, India  (O)
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_10.pdf
# page 1 contains address:
# (1) FG52+X65, Knowledge Park II, Greater Noida, Uttar Pradesh 201310, India
# page 2 contains address:
# page 3 contains address:
# (1) Roppen Transportation Services Private Limited 1st, No 179-D, Khasra no 78 Khirki Village, New Delhi, South Delhi, Delhi, 110017
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_37.pdf
# page 1 contains address:
# (1) 6:26 am | Maidan, Esplanade, Kolkata, West Bengal 700069, India
# (2) 7:15 am| Terminal Il, Room No: B-327, Netaji Subhash Chandra Bose International Airport, International Airport, Dum Dum, Kolkata, West Bengal 700052, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_11.pdf
# page 1 contains address:
# (1) « Opposite Railway Station, Janta Market, Alwar, Rajasthan 301001, India
# page 2 contains address:
# (1) Jaiki singh  Ola Micro, WagonR UP32KN4914  Operator State/UT: Uttar Pradesh
# (2) TC 14, Vijaipur Colony, Vibhuti Khand, Gomti Nagar, Lucknow, Uttar Pradesh 226010, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_8.pdf
# page 1 contains address:
# (1) CRN942935383 Thanks for travelling with us, Sant Singh
# (2) e N1, Khirki Main Road, Savitri Nagar, Block M, Malviya Nagar, New Delhi, Delhi 110017, India
# (3) D - 41, lower Ground Floor, Chaudhary Dalip Singh Marg, Kharera, Hauz Khas, New Delhi
# page 2 contains address:
# (1) Padam Singh  Ola Micro, WagonR o> HR55AB6730  Operator State/UT:  Delhi
# (2) N1, Khirki Main Road, Savitri Nagar, Block M, Malviya Nagar, New Delhi, Delhi 110017, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_3.pdf
# page 1 contains address:
# page 2 contains address:
# (1) Tower B, Rasoolpur Nawada, Industrial Area, Sector 62, Noida, Uttar Pradesh 201309,
# (2) DLF Building No. 7B, DLF Cyber City, DLF Phase 2, Sector 24, Gurugram, Haryana 122002, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO
India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_6.pdf
# page 1 contains address:
# (1) Thanks for riding, Jakison
# page 2 contains address:
# (1) Crossings Republik, Ghaziabad, Uttar Pradesh 201016, India
# page 3 contains address:
# (1) Area, Sector 62, Noida, Uttar Pradesh 201309, India
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_13.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 118, Butt Rd, Parangi Malai, St Thomas Mount, Chennai, Tamil Nadu 600016, India
# (2) Meenambakkam, Chennai, Tamil Nadu 600027, India
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_35.pdf
# page 1 contains address:
# (1) 1:43 pm| 24, B Narayanaswamappa Rd, Gokula 1st Stage, LIC Colony, Mathikere, Bengaluru, Karnataka 560022, India
# (2) 2:43 pm| Salarpuria Sattva Eminence, Kadubeesanahalli, Bengaluru, Bellandur Amanikere, Karnataka 560103, India

# %%
# extracting from UBER_2.pdf as example
def check_address(text):
    # Assumption: Address contains commas as seperator
    if ',' not in text: # Check if text doesn't have comma delimeter.
        return False
    # Assumption: Address Doesn't contain emails and hence no @ symbol 
    if '@' in text: # spacy considers text containing gmail address as location , so text containing gmail can never be address
        return False
    # this was an edge case found in invoices, through spacy NER , text containing thanks was also considered as location.
    if 'thank' in text : 
        return False
    doc = nlp(text)
    # Check if location is found in address 
    for entity in doc.ents:
        if entity.label_=='GPE' or entity.label_=='LOC':
            return True
    return False

def get_address():
    pdf=pdfplumber.open(os.getcwd()+'/pdf_dataset/UBER_2.pdf')
    address=[]
    for page in pdf.pages:
        img=np.array(page.to_image(resolution=300).original.convert('L'))
        ret, thresh1 = cv2.threshold(img, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)
        rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (16,16))   
        dilation = cv2.dilate(thresh1, rect_kernel, iterations = 3) 
        contours, _ = cv2.findContours(dilation,  cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
        for cnt in contours[::-1]: 
            x, y, w, h = cv2.boundingRect(cnt) 
            cropped = img[y:y + h, x:x + w]
            text=pytesseract.image_to_string(cropped)
            if check_address(text):
                address.append(text)
            if len(address)==2:
                return address
    return address    

for address in get_address():
    print(address.replace('\n',' ')+'\n')
# Out:
# 6/6, 3rd St, Shanthi Nagar, Adambakkam Shanthi Nagar, Adambakkam Chennai, Tamil Nadu 600088, Santhi Nagar, Adambakkam, Chennai, Tamil Nadu 600088, India
#
# 12:33pm Unnamed Road, Kovilancheri,  Tamil Nadu 600048, India

# %% [markdown]
# ### preprocess address text to remove time from address and non alphabetical / non numerical characters.

# %%
import re
import re
def preprocess_address_text(text):
   #remove time from string
   text= re.sub(r"\d{1,2}:\d{1,2}\s*(am|pm)?", '', text)
   #remove unwanted characters from address
   text= re.sub(r"[^a-zA-Z0-9,\s/-]", "", text)
   return text

print(preprocess_address_text('12:33pm Unnamed Road, Kovilancheri,  Tamil Nadu 600048, India '))
print(preprocess_address_text('© F-35, 2nd Ave, G Block, Anna Nagar, Sector B, Annanagar East, Chennai, Tamil Nadu 600040, India '))
print(preprocess_address_text(' 17:07  Haware Infotech Park, Sector 30A, Vashi, Navi Mumbai, Maharashtra 400703, India'))
# Out:
#  Unnamed Road, Kovilancheri,  Tamil Nadu 600048, India
#  F-35, 2nd Ave, G Block, Anna Nagar, Sector B, Annanagar East, Chennai, Tamil Nadu 600040, India
#  Haware Infotech Park, Sector 30A, Vashi, Navi Mumbai, Maharashtra 400703, India

# %%
# again checking for address , now taking  preprocessing in consideration
def image_to_rect(img):
    ret, thresh1 = cv2.threshold(img, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)
    rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (16,16))   
    dilation = cv2.dilate(thresh1, rect_kernel, iterations = 3) 
    contours, _ = cv2.findContours(dilation,  cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
    index=1
    for cnt in contours[::-1]: 
        x, y, w, h = cv2.boundingRect(cnt) 
        cropped = img[y:y + h, x:x + w]
        text=pytesseract.image_to_string(cropped).lower()
        if check_address(text):
            text=text.replace('\n',' ')
            print(f"({index}) {preprocess_address_text(text)}")
            index+=1
            
def generate_address_box(file):
    pdf=pdfplumber.open(file)
    print('file_name:',file)
    for page in pdf.pages:
      img=np.array(page.to_image(resolution=300).original.convert('L'))
      print(f'page {page.page_number} contains address:')
      image_to_rect(img)
    
path=os.getcwd()+'/pdf_dataset'
files=os.listdir(path)
for file in files:
  generate_address_box(path+'/'+file)
# Out:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_25.pdf
# page 1 contains address:
# (1) 55, gopalpura road, chhayadip nagar, shri gopal nagar, gopal pura mode, jaipur
# page 2 contains address:
# (1) pickup address 55, gopalpura road, chhayadip nagar, shri gopal nagar, gopal pura mode, jaipur
# page 3 contains address:
# (1) ani technologies pvt ltd  office unit 405 - 406, fourth floor, southend squire, mansarover industrial area, new sanganer road, jaipur south 302020
# (2) supply address office unit 405 - 406, fourth floor, southend squire, mansarover industrial area, new sanganer road, jaipur south 302020
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_3.pdf
# page 1 contains address:
# (1) e road number 23, andheri east, mumbai, maharashtra, india
# (2) karjat - murbad rd, kotwal nagar, deulwadi, karjat
# page 2 contains address:
# (1) road number 23, andheri east, mumbai, maharashtra, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_11.pdf
# page 1 contains address:
# page 2 contains address:
# (1) haware infotech park, sector 30a, vashi, navi mumbai, maharashtra 400703, india
# (2) 7, dongripada, thane west, thane, maharashtra 400607, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_33.pdf
# page 1 contains address:
# (1)   shyam colony, block f, budh vihar phase ii, budh vihar, new delhi, delhi 110041, india
# (2)   core-3, scope complex, 7-institutional area, lodhi road, cgo complex, pragati vihar, new delhi, delhi 110003, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_13.pdf
# page 1 contains address:
# (1) e s2 tie, kukatpally industrial estate, balanagar, hyderabad, telangana 520037, india
# (2) hyderabad airport post shihab road, shamshabad, gollapalle khurd eere eee eee
# page 2 contains address:
# (1) 2 tie, kukatpally industrial estate, balanagar, hyderabad, telangana 520037, india
# page 3 contains address:
# (1) o ola  ani technologies pvt ltd  ani technologies pvt ltd, hno1-98/2/11/8, 1 to 4 floors, srishti towers, opp karachi bakery, arunodaya co-op housing society, madhapur, hyderabad - 500081
# (2) ani technologies pvt ltd, hno1- 98/2/11/3, 1 to 4 floors, srishti towers, opp karachi bakery, arunodaya co-op housing society, madhapur, hyderabad - 500081
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_11.pdf
# page 1 contains address:
# (1) 70, talimabad, sangam vihar, new delhi, delhi 110062, india
# (2)  ff-07, first floor, salcon, rasvilas, saket district centre, district centre, sector 6, pushp vihar, new delhi, delhi 110017, india
# page 2 contains address:
# (1) customer pick up address 170, talimabad, sangam vihar, new delhi, delhi 110062, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179- d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vivek chaudhary 170, talimabad, sangam vihar, new delhi, delhi 110062, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_16.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 15, d-cabin, sabarmati, ahmedabad, gujarat 380019,
# (2) block 9, ground floor, udhyog bhawan, 4 circle, gh rd, sector 11, gandhinagar, gujarat 382010, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_30.pdf
# page 1 contains address:
# (1)   hotel olive eva opp inforpark kakkanad, kochi, kerala 682030, india
# (2)   vytila junction, opp corpration bulding, kochi, kerala 682019, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_7.pdf
# page 1 contains address:
# (1) 64, jubilee enclave, hitec city, hyderabad, telangana 500081, india
# page 2 contains address:
# (1) customer pick up address 64, jubilee enclave, hitec city, hyderabad, telangana 500081, india
# page 3 contains address:
# (1) roppen transportation services private limited 3rd floor, sai prithvi acrade, megha hills, sri  rama colony, madhapur, hyderabad,  telangana, 500081
# (2) tejo prakash kiran jasti 64, jubilee enclave, hitec city, hyderabad, telangana 500081, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_29.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   236/1, magadi main rd, lakshminarayanapuram, binnipete, bengaluru, karnataka 560023, india
# page 3 contains address:
# (1) gangamuthanahalli, karnataka 560300, india
# page 4 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_17.pdf
# page 1 contains address:
# (1) fg52x65, knowledge park il, greater noida, uttar pradesh 201310, india
# page 2 contains address:
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_2.pdf
# page 1 contains address:
# (1) 81/9, mehuwala mafi, dehradun, harbanswala, uttarakhand 248171, india
# (2)  7xqwhv6, isbt chowk, isbt, majra, dehradun, sewla khurd, uttarakhand 248171, india
# page 2 contains address:
# (1) customer pick up address 81/9, mehuwala mafi, dehradun, harbanswala, uttarakhand 248171, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_14.pdf
# page 1 contains address:
# (1)  platina building, g block bkc, bandra kurla complex, bandra east, mumbai, maharashtra 400051, india
# page 2 contains address:
# (1) platina building, g block bkc, bandra kurla complex, bandra east, mumbai, maharashtra 400051, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_21.pdf
# page 1 contains address:
# (1)   casa paradiso, allauddin basthi, sanath nagar, hyderabad, telangana 500018, india
# (2)   departure dr, shamshabad, hyderabad, telangana 501218, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_26.pdf
# page 1 contains address:
# (1)    187, block d, sector 61, noida, uttar pradesh 201301, india
# (2)    2/45, block 2, geeta colony, a feeei, delhi 110031, india
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_4.pdf
# page 1 contains address:
# page 2 contains address:
# (1)  904, trishla city, nabha, punjab 160403, india
# (2)   new civil air terminal, mohali district, sahibzada ajit singh nagar, punjab 140306, india
# page 3 contains address:
# page 4 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_15.pdf
# page 1 contains address:
# (1) 18c, knowledge park ill, noida, uttar pradesh 201310, india
# page 2 contains address:
# (1) customer pick up address 18c, knowledge park iii, noida, uttar pradesh 201310, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vijayguna 18c, knowledge park iii, noida, uttar pradesh 201310, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_16.pdf
# page 1 contains address:
# (1) chhatrapati shivaji terminus, fort, mumbai
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_16.pdf
# page 1 contains address:
# (1) india expo mart cir, knowledge park ii, greater noida, uttar pradesh 201310, india
# (2)  2c, near iimt college, knowledge park iii, greater noida, uttar pradesh 201310, india
# page 2 contains address:
# (1) customer pick up address india expo mart cir, knowledge park ii, greater noida, uttar pradesh 201310, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vijayguna india expo mart cir, knowledge park ii, greater noida, uttar pradesh 201310, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_22.pdf
# page 1 contains address:
# (1)  1431/1, 4th cross rd, rashad nagar, govindapura, hbr layout, bengaluru, karnataka 560045, india
# (2)  rk puram, gandhi nagar, bengaluru, karnataka 560009, india
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_15.pdf
# page 1 contains address:
# page 2 contains address:
# (1) dlf phase 5, sector 54, gurugram, haryana 122002,  india
# (2)  delhi, 110037, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_18.pdf
# page 1 contains address:
# (1)   road number ce124  salt lake, sector  1, kolkata india  19 ns road, hmp house  bbd bagh, dalhousie, kolkata india
# page 2 contains address:
# (1) road number 23, andheri east, mumbai, maharashtra, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_4.pdf
# page 1 contains address:
# (1) unnamed road, kavuri hills phase 1, kavuri hills, jubilee hills, hyderabad, telangana 500033, india  e block ysr residency, barkatpura rd, chitrapuri colony, lingampally, kachiguda, hyderabad, telangana 500027, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_6.pdf
# page 1 contains address:
# (1) 40, moosapet cross rd, pragathi nagar, moosapet, hyderabad, telangana 500018, india
# (2)  cgm2ghr, railway officer colony, botiguda, bhoiguda, secunderabad, telangana 500003, india
# page 2 contains address:
# (1) customer pick up address 40, moosapet cross rd, pragathi nagar, moosapet, hyderabad, telangana 500018, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_24.pdf
# page 1 contains address:
# (1)   delhi, 110037, india
# (2)   ms-4, kendriya vihar, sector 56, gurugram, haryana 122011, india
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_15.pdf
# page 1 contains address:
# (1)  13, navpada, cs international airport area, vile parle, mumbai, maharashtra 400099, india
# page 2 contains address:
# (1) 13, navpada, cs international airport area, vile parle, mumbai, maharashtra 400099, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_39.pdf
# page 1 contains address:
# (1)   sant nagar, sundar nagar, new delhi, delhi 110003, india
# (2)  narmadeshwar niwas beside narmadeshwar shiv mandir b block, sector 62, nearby b block market, block b, industrial area, sector 62, noida, uttar pradesh 201309, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_38.pdf
# page 1 contains address:
# (1)  hyderabad - ramagundam rd, shamirpet, secunderabad, telangana 500078, india
# (2)   65/a vengalrao nagar, east srinivas nagar colony, sanjeeva reddy nagar office area, sanjeeva reddy nagar, hyderabad, telangana 500038, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_4.pdf
# page 1 contains address:
# (1) minimum bill of 100 for the first 4 km and 8/km thereafter ride time at 710 per min, includes waiting time during the trip  additional service tax is applicable on your fare total fare includes this additional service tax total bill also includes any toll, mcd or state tax if applicableclick here for details  we levy peak pricing charges when the demand is high, so that we can make more cabs available to you and continue to serve you efficiently  for queries or complaints, please visit our support page  this is an electronically generated invoice and does not require signature all terms and conditions are as given on  wwwolacabscom  a wing sunteck centre, 37-40 subhash road, off western express highway, vile parle east, mumbai - 400057 service lax  aajca1389gs d001, service tax category cab operator, pan no aajca1389g,  cinu72900mh2010p tc 240894 rl 91 22 3355 3355, fax 022 30947974 wwwolacabscom  ani technologies pvt ltd
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_25.pdf
# page 1 contains address:
# (1)   park plaza, mother teresa sarani, taltala, kolkata, west bengal 700016, india
# (2)   biswa bangla sarani, action area iie, sukanta pally, newtown, new town, west bengal 700157, india
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_18.pdf
# page 1 contains address:
# (1) knowledge park ii, greater noida, uttar pradesh 201310, india
# page 2 contains address:
# (1) customer pick up address knowledge park ii, greater noida, uttar pradesh 201310, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vijayguna knowledge park ii, greater noida, uttar pradesh 201310, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_31.pdf
# page 1 contains address:
# (1)   12, khatipura rd, parivahan nagar, khatipura, jaipur, rajasthan 302012, india
# (2)   sb-108, sawai mansingh rd, bapu nagar, jaipur, rajasthan 302007, india
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_17.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   6-3-581/1/1, anand nagar rd, venkataraman colony, khairtabad, hyderabad, telangana 500004, india
# (2) kacigua,  pact
# (3)   nimboliadda, kachiguda, hyderabad, telangana 500027, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_19.pdf
# page 1 contains address:
# (1)  201310, near punjab national bank, amritpuram, block e, chandila, gamma 1, greater noida, uttar pradesh 201308, india
# (2) fg52x65, knowledge park ii, greater noida, uttar pradesh 201310, india
# page 2 contains address:
# (1) customer pick up address  201310, near punjab national bank, amritpuram, block e, chandila, gamma 1, greater noida, uttar pradesh 201308, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vijayguna  201310, near punjab national bank, amritpuram, block e, chandila, gamma 1, greater noida, uttar pradesh 201308, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_2.pdf
# page 1 contains address:
# (1) note this is an electronically generated invoice and does not require signature all terms and conditions are as given on wwwolacabscom  a wing sunteck centre, 37-40 subhash road, off western express highway, vile parle east, mumbai - 400057 service lax  aajca1389gs d001, service tax category cab operator, pan no aajca1389g, cinu72900mh2010p tc 240894 rl 91 22 3355 3355, fax 022 30947974 wwwolacabscom  ani technologies pvt ltd
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_34.pdf
# page 1 contains address:
# page 2 contains address:
# (1) noapara, sukanta pally,
# (2) rajarhat, west bengal
# (3) 700157, india
# (4) 30, action area , newtown,
# (5) new town, west bengal
# (6) 700156, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_6.pdf
# page 1 contains address:
# (1)  b-74, mehuwala mafi, dehradun, uttarakhand 248171, india
# (2) in case of any complaint/grievance against this invoice, write to us at  grievance officer, ani technologies private limited, ola campus, prestige rmz star tech, c wing, koramangala industrial layout, koramangala, hosur road, bengaluru, karnataka, 560095
# page 2 contains address:
# (1) b-74, mehuwala mafi, dehradun, uttarakhand 248171, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_19.pdf
# page 1 contains address:
# (1)   krishnappa garden, c v raman nagar, bengaluru, karnataka 560075, india
# (2)   windmills of your mind, 331, 5b rd, shivaji nagar, kiadb export promotion industrial area, whitefield, bengaluru, karnataka 560066, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_13.pdf
# page 1 contains address:
# (1) 281c, near iimt, knowledge park ill, greater noida, uttar pradesh 201310, india
# (2) fg53m6 greater noida, uttar pradesh, india
# page 2 contains address:
# (1) customer pick up address 281c, near iimt, knowledge park iii, greater noida, uttar pradesh 201310, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2) vijayguna 281c, near iimt, knowledge park iii, greater noida, uttar pradesh 201310, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_5.pdf
# page 1 contains address:
# page 2 contains address:
# (1) dlf phase 5, sector 54, gurugram, haryana 122002,  india
# (2) delhi, 110037, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_7.pdf
# page 1 contains address:
# (1) bashettihalli          oases, halli 3  paar sulibel  or 648 makali ava 75 whitefield istzeert koramangala boedebortes fas  google map data 2018 google
# (2) 786, 1st main rd, 1st block, dubasi palya, kengeri satellite town, bengaluru, karnataka 560059, india
# (3) atc tower, bial road, bengaluru
# page 2 contains address:
# (1) kengeri satellite town, bengaluru, karnataka 560059,  india
# page 3 contains address:
# (1) ani technologies pvt ltd  5th floor, maruthi infotech center, 100 feet rd, embassy golf links business park, domlur, bengaluru, karnataka 560071
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_12.pdf
# page 1 contains address:
# (1) sep 19th 2022,
# (2) h block, sector 62, noida, uttar pradesh 201301, india
# (3)  8-910, assotech cabana, vaibhav khand, indirapuram, ghaziabad, uttar pradesh 201014, india
# page 2 contains address:
# (1) sep 19th 2022,
# (2) customer pick up address h block, sector 62, noida, uttar pradesh 201301, india
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# (2
india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_23.pdf
# page 1 contains address:
# (1) 27225rc, kasturba nagar 3rd cross st, venkata rathnam nagar extension, venkata rathinam nagar, adyar, chennai
# (2) meenambakkam, chennai - theni hwy, national airports authority colony, meenambakkam, nandanvakkam, chennai
# (3) grievance officer, ani technologies private limited, ola campus, prestige rmz star tech, c wing, koramangala industrial layout, koramangala, hosur road, bengaluru, karnataka, 560095
# page 2 contains address:
# (1) pickup address 27225rc, kasturba nagar 3rd cross st, venkata rathnam nagar extension, venkata rathinam  nagar, adyar, chennai
# page 3 contains address:
# (1) ani technologies pvt ltd  ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal, arumbakkam,chennai
# (2) supply address ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal,  arumbakkam,chennai
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_40.pdf
# page 1 contains address:
# (1)  the forum mall, 21, hosur rd, chikku lakshmaiah layout, koramangala, bengaluru, karnataka 560095, india
# (2)  kempegowda international airport bengaluru, t2 terminal, bengaluru, karnataka 560300, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_5.pdf
# page 1 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_21.pdf
# page 1 contains address:
# (1) invoice no171226734 10 jan, 2016
# (2) chennai, cab, mini
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_12.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   nscbi airport,dum dum, airport terminal 2, international airport, dum dum, kolkata, west bengal 700052, india
# page 3 contains address:
# (1) nagar, tollygunge, kolkata, west bengal 700040, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_9.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   189, udyog vihar phase 1, udyog vihar, sector 20, gurugram, haryana 122008,  india
# (2)   6/82, jnarera, jharera village, delhi cantonment, new delhi, delhi 110010,
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_10.pdf
# page 1 contains address:
# page 2 contains address:
# (1) vimlesh kumar ola micro, xcent hr55ae9928 operator state/ut delhi
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_22.pdf
# page 1 contains address:
# (1) aravakkam,  a
# (2) base fare of 80 for the first 4 km and 10/km thereafter ride time at 10 per min after first 5 min, includes waiting time during the trip  additional service tax is applicable on your fare total fare includes this additional service tax toll and parking charges are extra  we levy peak pricing charges when the demand is high, so that we can make more cabs available to you and continue to serve you efficiently  for queries or complaints, please visit our support page  this is an electronically generated invoice and does not require signature all terms and conditions are as given on  wwwolacabscom  a wing sunteck centre, 37-40 subhash road, off western express highway, vile parle east, mumbai - 400057 service lax  aajca1389gs d001, service tax category cab operator, pan no aajca1389g, cinu72900mh2010p tc 240894  rl 91 22 3355 3355, fax 022 30947974 wwwolacabscom ani technologies pvt ltd
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_27.pdf
# page 1 contains address:
# (1) 4th main,ramapriya brundavan gardan arehallii, bengaluru, karnataka 560061, india  o
# page 2 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_10.pdf
# page 1 contains address:
# (1) fg52x65, knowledge park ii, greater noida, uttar pradesh 201310, india
# page 2 contains address:
# page 3 contains address:
# (1) roppen transportation services private limited 1st, no 179-d, khasra no 78 khirki village, new delhi, south delhi, delhi, 110017
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_37.pdf
# page 1 contains address:
# (1)   maidan, esplanade, kolkata, west bengal 700069, india
# (2)  terminal il, room no b-327, netaji subhash chandra bose international airport, international airport, dum dum, kolkata, west bengal 700052, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_11.pdf
# page 1 contains address:
# (1)  opposite railway station, janta market, alwar, rajasthan 301001, india
# page 2 contains address:
# (1) tc 14, vijaipur colony, vibhuti khand, gomti nagar, lucknow, uttar pradesh 226010, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_8.pdf
# page 1 contains address:
# (1) e n1, khirki main road, savitri nagar, block m, malviya nagar, new delhi, delhi 110017, india
# page 2 contains address:
# (1) n1, khirki main road, savitri nagar, block m, malviya nagar, new delhi, delhi 110017, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_3.pdf
# page 1 contains address:
# page 2 contains address:
# (1) tower b, rasoolpur nawada, industrial area, sector 62, noida, uttar pradesh 201309,
# (2) dlf building no 7b, dlf cyber city, dlf phase 2, sector 24, gurugram, haryana 122002, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_3.pdf
# page 1 contains address:
# (1) shop no1, lgf, capri trade center,, chakarata road, old cannaught place, chukkuwala, dehradun, uttarakhand 248001, india
# (2)  8x6q4qg, mehuwala mafi, dehradun, harbanswala, uttarakhand 248171, india
# page 2 contains address:
# (1) customer pick up address  shop no1, lgf, capri trade center,, chakarata road, old cannaught place, chukkuwala, dehradun, uttarakhand 248001, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_9.pdf
# page 1 contains address:
# (1) 19, lb rd, baktavatsalm nagar, adyar, chennai, tamil nadu 600020, india
# (2)  f-35, 2nd ave, g block, anna nagar, sector b, annanagar east, chennai, tamil nadu 600040, india
# page 2 contains address:
# (1) passengers nec, onl
# (2) customer pick up address 19, lb rd, baktavatsalm nagar, adyar, chennai, tamil nadu 600020, india
# page 3 contains address:
# (1) roppen transportation services private limited 78, old door no 34/a, mount road, guindy, chennai, tamil nadu 600032
# (2) hari krishna 19, lb rd, baktavatsalm nagar, adyar, chennai, tamil nadu 600020, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_28.pdf
# page 1 contains address:
# page 2 contains address:
# (1) sra-sy, crash rd, vazhakkala, kakkanad, kerala 682021, india
# (2) roshan ln, kacheripady, ernakulam, kerala 682018,
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_5.pdf
# page 1 contains address:
# (1) pf 10, railway officer colony, botiguda, bhoiguda, secunderabad, telangana
# (2) 500025, india
# (3)  17-1-178/a/15/a, near raheem function hall, salala nagar, santosh nagar, hyderabad, telangana 500059, india
# page 2 contains address:
# (1) customer pick up address  pf10, railway officer colony, botiguda, bhoiguda, secunderabad, telangana 500025, india
# page 3 contains address:
# (1) roppen transportation services private limited 3rd floor, sai prithvi acrade, megha hills, sri  rama colony, madhapur, hyderabad, telangana, 500081
# (2) mastanvali shaik  pf10, railway officer colony, botiguda, bhoiguda, secunderabad, telangana 500025, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_10.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   unnamed road, shamshabad, hyderabad, telangana 501218, india
# (2)   sai jyothi apartment, creative nagar, dr as rao nagar, secunderabad, telangana 500062, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_24.pdf
# page 1 contains address:
# (1) 27225rc, kasturba nagar 3rd cross st, venkata rathnam nagar extension, venkata rathinam nagar, adyar, chennai
# (2) meenambakkam, chennai - theni hwy, national airports authority colony, meenambakkam, nandanvakkam, chennai
# (3) grievance officer, ani technologies private limited, ola campus, prestige rmz star tech, c wing, koramangala industrial layout, koramangala, hosur road, bengaluru, karnataka, 560095
# page 2 contains address:
# (1) pickup address 27225rc, kasturba nagar 3rd cross st, venkata rathnam nagar extension, venkata rathinam  nagar, adyar, chennai
# page 3 contains address:
# (1) ani technologies pvt ltd  ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal, arumbakkam,chennai
# (2) supply address ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal,  arumbakkam,chennai
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_14_!.pdf
# page 1 contains address:
# page 2 contains address:
# (1)   arrival dr, shamshabad, hyderabad, telangana 501218, india
# (2)   subodaya luxury apartments, ywca road, bogulkunta, hyderguda, hyderabad, telangana 500001, india
# page 3 contains address:
# page 4 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_7.pdf
# page 1 contains address:
# page 2 contains address:
# (1)  new airport rd, borjhar,  guwahati, assam 781015, india
# (2)   tripura rd, resham nagar, khanapara, guwahati, assam 781038, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_2.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 6/6, 3rd st, shanthi nagar, adambakkam shanthi nagar, adambakkam chennai, tamil nadu 600088, santhi nagar, adambakkam, chennai, tamil nadu 600088, india
# (2)  unnamed road, kovilancheri,  tamil nadu 600048, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_9.pdf
# page 1 contains address:
# (1) vv kudlu ad  ngasandra  s jegur alow,  ciingie
# (2) mangalore international airport mangalore, karnataka 574142, india
# (3) udupi bus stand udupi, karnataka
# page 2 contains address:
# (1) 916366161696 mangalore international airport bajpe main rd, kenjar hc, mangalore, karnataka
# page 3 contains address:
# (1)    o ola  ani technologies pvt ltd  5th floor, maruthi infotech center, 100 feet rd, embassy golf links business park, domlur, bengaluru, karnataka 560071           cidvswww0324488
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_12.pdf
# page 1 contains address:
# (1)  survey no 169, old mahabalipuram rd, kumaran nagar, chemmanchery, chennai, tamil nadu 600119, india
# page 2 contains address:
# (1) survey no 169, old mahabalipuram rd, kumaran nagar, chemmanchery, chennai, tamil nadu 600119, india
# page 3 contains address:
# (1) o ola  ani technologies pvt ltd  ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal, arumbakkam, chennai
# (2) ani technologies pvtltd, 18-a, sidco industrial area, mmda bus terminal, arumbakkam, chennai
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/OLA_17.pdf
# page 1 contains address:
# (1) le map data 2018 google  kantekar arun  micro - white wagonr  kantekar arun  ola micro, wagonr mh12tb1397 operator state/ut maharashtra
# (2) , imd colony road, ward no 8, imd colony, pashan, pune
# page 2 contains address:
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_8.pdf
# page 1 contains address:
# page 2 contains address:
# (1) mindspace rd, rolling hills, p janardhan reddy nagar, gachibowli, hyderabad, telangana 5000871, india
# (2)   food court, level b, rajiv gandhi international airport, shamshabad, hyderabad, telangana 501218, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/RAPIDO_1.pdf
# page 1 contains address:
# (1) b-92, mehuwala mafi, dehradun, harbanswala, uttarakhand 248171, india
# (2)  dehradun parade graund, darshan lal chowk, race course, dehradun, uttarakhand 248001, india
# page 2 contains address:
# (1) customer pick up address b-92, mehuwala mafi, dehradun, harbanswala, uttarakhand 248171, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_6.pdf
# page 1 contains address:
# page 2 contains address:
# (1) crossings republik, ghaziabad, uttar pradesh 201016, india
# page 3 contains address:
# (1) area, sector 62, noida, uttar pradesh 201309, india
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_13.pdf
# page 1 contains address:
# page 2 contains address:
# (1) 118, butt rd, parangi malai, st thomas mount, chennai, tamil nadu 600016, india
# (2) meenambakkam, chennai, tamil nadu 600027, india
# page 3 contains address:
# file_name: /home/panwar2001/Desktop/TEST/2023-10-09-ESS1/AI/pdf_dataset/UBER_35.pdf
# page 1 contains address:
# (1)  24, b narayanaswamappa rd, gokula 1st stage, lic colony, mathikere, bengaluru, karnataka 560022, india
# (2)  salarpuria sattva eminence, kadubeesanahalli, bengaluru, bellandur amanikere, karnataka 560103, india
